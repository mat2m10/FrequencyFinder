# %% [markdown]
# # Finding frequency from synthetisch data

# %% [markdown]
# ## Import Libraries

# %%
import os
import getpass
import subprocess

# %% [markdown]
# ## Fetching data

# %% [markdown]
# ### Finding absolute path to external drive

# %%
username = getpass.getuser() # Finding the username of the user
array_disks = !lsblk -o NAME -nl # All the disks in use
if "sda1" in array_disks:
    path = "/dev/sda1"
elif "sda" in array_disks:
    path = "/dev.sda"
bashCommand = f"findmnt -A {path}" # to find the path of the place where mounted
process = subprocess.Popen(bashCommand.split(), stdout=subprocess.PIPE)
output, error = process.communicate()
path_to_external_drive = output.decode('ascii').split('\n')[1].split(' ')[0] # Using the output

# %%
path_to_external_drive
# Out:
# '/media/mat2m10/Samsung_T5'

# %%
syn_data = pd.read_pickle(f"{path_to_external_drive}/Data/Inputs/Synthetisch/chr_19_geno_pheno_covs_poplabels.pkl")
